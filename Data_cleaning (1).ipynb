# %% [markdown]
# # 1. What is data cleaning,and why is it important in data analysis?
#
# ANS-
#
# Data cleaning is the process of identifying and correcting errors, inconsistencies, and incompleteness in a dataset to enhance its quality and reliability. This process is crucial in data analysis because it ensures accurate and reliable insights, leading to better decision-making.
#
# # . What are the potential consequences of analyzing unclean or messy data?
#
# -Analyzing unclean or messy data can lead to incorrest conclusions and poor decision making.
#
# -It may also reduce the reliablity and accuracy of results,causing wasted time and resources.
#
# # . Explain the common steps involved in cleaning and organizing data.
#
# -Common steps involved in cleaning and organizing data are:-
#
# .Removing duplicates.
#
# .Handling missing values.
#
# .Correcting errors.
#
# .Standardizing formates
#
# After cleaning,data is organized by structuring it properly,labeling variables,and sorting or categorizing it for easy analysis.

# %% [markdown]
# # 2. How  would you start the following dataset firdt by"Department"(A-Z)and then by "Salary"(Largest to smallest)? write a step-by-step apporach.
#
# Ans-
#
# Steps involed in sorting-
#
# 1.Select the full table
#
# 2.Go to data->Sort
#
# 3.Add Level 1:Column:Department Order:A to Z
#
# 4.Add Level 2:Column:Salary Order:Largest to smallest
#
# 5.Click OK
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #3. Explain the use of text functions such as TRIM,LEFT,RIGHT,MID,and CONCAT in data cleaning.
#
# Ans-
#
# . TRIM: This function removes leading or trailing spaces (or other specified characters) from a text string, which is crucial for standardizing data and preventing matching errors.
#
#
# . LEFT: The LEFT function extracts a specified number of characters from the beginning (left side) of a text string, useful for isolating prefixes or codes.
#
#
# . RIGHT: Similarly, the RIGHT function extracts a specified number of characters from the end (right side) of a text string, often used for extracting suffixes or specific identifiers.
#
#
# . MID: The MID function extracts a substring from a text string, starting at a specified position and for a specified length, allowing for extraction of data from within a larger string.
#
#
# . CONCAT: The CONCAT function joins two or more text strings together into a single string, which is useful for combining disparate data fields into a more meaningful whole, such as creating full names from first and last names.

# %% [markdown]
# # 4. What is the role of data functions like TODAY in managing datasets?
#
# Ans-
#
# TODAY() fuction returns date automaticaly and updates daily which returns current date.

# %% [markdown]
# #5. Apply Data validation to restrict Quantity values to only whole numbers between 1 and 10.
#
# #a. Configure an input message that appears when a user selects a cell in the "Quantity" column explaining: "please enter a whole number between 1 and 10."
#
# #b. Set up an error alert message that triggers if the user enters a number less than 1 or greater than 10, showing:
# #"Invalid input! The quantity must be a whole number between 1 and 10."
#
# Ans-
#
# a.Input Message-
#
# 1.Select Quantity column
#
# 2.Go to Data - Data Validation
#
# 3.Settings:
#
# Allow: Whole Numbers
# Between: 1 and 10
#
# 4.Input Message tab:
#
# Title: Input Required
#
#  Message: Please enter a whole number between 1 and 10.
#
# b. Error Alert
#
#  Style: Stop
#
#   Message:
#
#  Invalid input! The quantitymust be a whole number between 1 and 10.
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# #6. U nderstand and apply fundamental text functions like LEFT, RIGHT, MID, and LEN.
#
# #1. Extract the first 5 characters from the string "ExcelTipsAreGreat" using the LEFT function.
#
# Ans-
#
# =LEFT("ExcelTipsAreGreat",5)
#
# Excel
#
# #2. Extract the last 4 characters from "DataAnalysis.xlsx" using the RIGHT function.
#
# Ans-
#
# =RIGHT("DataAnalysis.xlsx",4)
#
# xlsx
#
# #3. Extract the substring "Tips" from "ExcelTipsAreGreat" using the MID function.
#
# Ans-
#
# =MID("ExcelTipsAreGreat",6,4")
#
# Tips
#
# #4. Count the total number of characters in the string "Hello World!" using the LEN function.
#
# Ans-
#
# =LEN("Hello World!")
#
# 12
#
# #5. Create a formula to extract the middle 6 characters from "12345-67890-ABCDE".
#
# Ans-
#
# =MID("12345-67890-ABCDE",7,6)
#
# -67890

# %% [markdown]
# #7.Understand how to combine text using CONCAT, TEXTJOIN, and the & operator.
#
# #1. Use CONCAT to combine "Hello" and "World" with a space in between.
#
# Ans-
#
# =CONCAT("Hello",","World")
#
# Hello World
#
# #2. Combine "Apple", "Banana", and "Cherry" into a single string separated by commas using TEXTJOIN.
#
# Ans-
#
# =TEXTJOIN(",",TRUE,"Apple","Banana","Cherry")
#
# Apple,Banana,Cherry
#
# #3. Use the & operator to create the string "2025: Excel Functions" by combining "2025", ": ", and "ExcelFunctions".
#
# ="2025"&":"&"Excel Functions"
#
# 2025:Excel Functions
#
# #4. Create a comma-separated list from the range A1:A5 using TEXTJOIN
#
# Ans-
#
# =TEXTJOIN(",",TRUE,A1:A5)
#
# #5. Combine first names in column A with last names in column B to create full names in column C
#
# Ans-
#
# =A1&""&B1

# %% [markdown]
# #8. Understanding TODAY() and NOW()
#
#  #a. What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use each function.
#
#  Ans-
#
#  **TODAY**-This function returns the current date only,without the time component. It updates automatically whenever the worksheet is opened or recalculated.
#
#  EX- TODAY()
#
#  29/03/2026
#
#  **NOW**- This fuction returns the both current date and the current time and updates automatically whenever the worksheet is opened.
#
#  EX- NOW()
#
#  29/03/2026 13:45
#
# #b. If cell A1 contains the date 2025-06-10, write a formula using TODAY() to determine how many days are left until that date
#
# Ans-
#
# =A1-TODAY()
#
# #c. Write an Excel formula using NOW() to display the current date and time in the format MM/DD/YYYY HH:MM AM/PM. ́
#
# Ans-
#
# =TEXT(NOW(),"MM/DD/YYYY HH:MM AM/PM")
#
# 03/29/2026 13:45 PM
#
# #d. If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain
#
# Ans-
#
# It updates the date automatically whenever the worksheet is opend.
#
# #e. You want to store a static date (today’s date) in a cell without it changing every day. What keyboard shortcut should you use?
#
# Ans-
#
# cntrl+;
